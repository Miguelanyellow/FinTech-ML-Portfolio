# %%
#Se monta el Drive:
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.append('/content/drive/MyDrive/Projects/FinTech-ML-Portfolio/2_scripts')

from trainer import trainer

# %%
# !pip install -q optuna
# !pip install -q --upgrade prophet
# !pip install -q --upgrade yfinance
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 395.9/395.9 kB 8.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.0/247.0 kB 16.6 MB/s eta 0:00:00

# %%
trainer('NVDA.MX', trials=300, peri=1, hori=5, FHi='2023-01-01', guardar=True, logi=True)
# Out:
# [*********************100%***********************]  1 of 1 completed
# ...
#   0%|          | 0/527 [00:00<?, ?it/s]

# %%
models = {}
lis = list(range(5, 6))  # horizontes

tckr = 'GOOGL.MX'
for i in lis:
  Print(f'Ajustando el modelo para el horizonte {i}')
  label = f'{tckr}_{i}'
  #models[label] = trainer(tckr, trials=55, FHi='2023-01-01', peri=1, hori=i)
