# %% [markdown]
# # 📦 ChangeLog Notebook – FinTech-ML-Portfolio
#
# This notebook documents key version control actions across the FinTech-ML-Portfolio project.
# Each entry includes commit details, deployment methods, and outcomes to ensure technical traceability of modeling workflows and code evolution.
#
# > Designed to support data science practices aligned with regulatory compliance, forecasting accuracy, and collaborative development.

# %% [markdown]
# ## 🗓️ 2025-07-16 – Branch `preliminar` Push
#
# - Commit with Prophet + Optuna models for financial assets FUNO1 and ADBE
# - Token loaded securely via `.env` using HTTPS authentication
# - Branch `preliminar` published for future review, performance validation, and potential merge into `main`

# %% [markdown]
# ## 🗓️ 2025-07-16 README.md Deploymen
#
# **Commit:** `📝 Add project overview README with modeling workflow`
# **Branch:** `main`
#
# **Change summary:**
# Created and published the `README.md` file as the official landing page for the FinTech-ML-Portfolio repository. Highlights include:
#
# - Contextual overview of the project: financial forecasting with regulatory alignment
# - Folder and workflow structure for modeling notebooks and training scripts
# - Secure Git authentication setup using Personal Access Token
# - Stack overview detailing core libraries and tools
#
# **Deployment method:**
# - Repository cloned locally via Visual Studio Code
# - Markdown authored with live preview
# - Commit executed from integrated terminal
# - Push authenticated via Git Credential Manager (Windows)
#
# **Result:**
# The `README.md` file is now published and visible on the repository homepage:
# 🔗 [github.com/Miguelanyellow/FinTech-ML-Portfolio](https://github.com/Miguelanyellow/FinTech-ML-Portfolio)
#
# ---
#
# > This changelog notebook captures iterative improvements, technical decisions, and architectural milestones throughout project development.

# %% [markdown]
# ## 🗓️ July 17, 2025 – Rebase and Push of `preliminar` Branch
#
# **Local Commit:**
# 💾 `"Local edits before syncing with main"` — commits included changes in `The-Model-Trainer.ipynb` and the creation of `ChangeLog.ipynb`, made within the Drive-based repo before updating the `README.md` from VS Code.
#
# **Technical Event:**
# The `preliminar` branch was successfully rebased onto `main`, which had received the commit `📝 Add project overview README`. Git reorganized the local commit history to follow the new base from `main`. A previously applied commit (`c011d25`) was skipped automatically as part of Git’s conflict avoidance strategy.
#
# **Rebase Output:**
# ```text
# Successfully rebased and updated refs/heads/preliminar
# [skipped] previously applied commit c011d25

# %% [markdown]
# ## 🗓️ 2025-07-17 – Model Commit: GOOGL.MX (Short-Term)
#
# - 📦 Added trained model artifact: `model_googlmx_1.pkl`
# - 🧠 Target asset: GOOGL.MX – short-term forecasting
# - 📘 Updated notebooks: `AssetXplore`, `Model-Trainer`, `ChangeLog`
# - 🧪 Updated scripts: `trainer.py`
# - 🔐 Excluded binary cache: `__pycache__`
